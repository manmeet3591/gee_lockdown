# %%
from IPython.display import Image
import ee, folium
import os
#import folium.colormap as cm
import branca
import branca.colormap as cm
ee.Initialize()
print (folium.__file__)
print (folium.__version__)
# Out:
# /home/manmeet/anaconda3/envs/py36/lib/python3.6/site-packages/folium/__init__.py
# 0.11.0

# %%
collection20 = ee.ImageCollection('MODIS/006/MCD19A2_GRANULES').select('Optical_Depth_055').filterDate('2020-03-23', '2020-05-31').mean()
collection19 = ee.ImageCollection('MODIS/006/MCD19A2_GRANULES').select('Optical_Depth_055').filterDate('2019-03-23', '2019-05-31').mean()
no2_diff = collection19.subtract(collection20)
no2_diff = no2_diff.divide(collection19).multiply(100)

roi = ee.Geometry.Rectangle([60, 5, 98.5+5, 37])
band_viz = {
  'min': -50,
  'max': 50,
  #'palette': ['yellow', 'orange', 'red']
  'palette': ['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red']
}
colormap = cm.LinearColormap(['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red'], vmin=-50, vmax=50)
#colormap = cm.linear.YlOrRd_09.scale(0, 0.0002).to_step(10)
colormap.caption = '% change in aerosol optical depth'
no2_diff = collection19.subtract(collection20)
no2_diff = no2_diff.divide(collection19).multiply(100)
mapid = no2_diff.clip(roi).getMapId(band_viz)

map = folium.Map(location=[24.11+2,75.27+5],zoom_start=4, height=550,width=600)

folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='AOD',
    opacity=0.2,
  ).add_to(map)

map.add_child(folium.LayerControl())
map.add_child(colormap)
#folium.map.LayerControl('topleft', collapsed=False).add_to(map)
title_html = '''
             <h3 align="center" style="font-size:20px"><b>AOD % change (2019-2020) </b></h3>
             '''
map.get_root().html.add_child(folium.Element(title_html))

map.save('aod_india.html')
map
os.system("wkhtmltopdf --dpi 1000 aod_india.html aod_india.pdf")
os.system("pdfcrop --margins '0 0 0 0' aod_india.pdf")
# Out:
# 0

# %%
collection20 = ee.ImageCollection('MODIS/006/MCD19A2_GRANULES').select('Optical_Depth_055').filterDate('2020-03-23', '2020-05-31').mean()
collection19 = ee.ImageCollection('MODIS/006/MCD19A2_GRANULES').select('Optical_Depth_055').filterDate('2019-03-23', '2019-05-31').mean()
no2_diff = collection19.subtract(collection20)
no2_diff = no2_diff.divide(collection19).multiply(100)

roi = ee.Geometry.Rectangle([65+30, 5-15, 98.5+40, 37-15])
band_viz = {
  'min': -50,
  'max': 50,
  #'palette': ['yellow', 'orange', 'red']
  'palette': ['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red']
}
colormap = cm.LinearColormap(['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red'], vmin=-50, vmax=50)
#colormap = cm.linear.YlOrRd_09.scale(0, 0.0002).to_step(10)
colormap.caption = '% change in aerosol optical depth'
no2_diff = collection19.subtract(collection20)
no2_diff = no2_diff.divide(collection19).multiply(100)
mapid = no2_diff.clip(roi).getMapId(band_viz)

map = folium.Map(location=[24.11-15,75.27+40],zoom_start=4, height=550,width=600)

folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='AOD',
    opacity=0.2,
  ).add_to(map)

map.add_child(folium.LayerControl())
map.add_child(colormap)
#folium.map.LayerControl('topleft', collapsed=False).add_to(map)
title_html = '''
             <h3 align="center" style="font-size:20px"><b>AOD % change (2019-2020) </b></h3>
             '''
map.get_root().html.add_child(folium.Element(title_html))

map.save('aod_seasia.html')
map
os.system("wkhtmltopdf --dpi 1000 aod_seasia.html aod_seasia.pdf")
os.system("pdfcrop --margins '0 0 0 0' aod_seasia.pdf")
# Out:
# 0

# %%
collection20 = ee.ImageCollection('MODIS/006/MCD19A2_GRANULES').select('Optical_Depth_055').filterDate('2020-01-24', '2020-03-25').mean()
collection19 = ee.ImageCollection('MODIS/006/MCD19A2_GRANULES').select('Optical_Depth_055').filterDate('2019-01-24', '2019-03-25').mean()
no2_diff = collection19.subtract(collection20)
no2_diff = no2_diff.divide(collection19).multiply(100)
roi = ee.Geometry.Rectangle([65+30, 5+10, 98.5+50, 37+10-2])
band_viz = {
  'min': -50,
  'max': 50,
  #'palette': ['yellow', 'orange', 'red']
  'palette': ['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red']
}
colormap = cm.LinearColormap(['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red'], vmin=-50, vmax=50)
#colormap = cm.linear.YlOrRd_09.scale(0, 0.0002).to_step(10)
colormap.caption = '% change in aerosol optical depth'
no2_diff = collection19.subtract(collection20)
no2_diff = no2_diff.divide(collection19).multiply(100)
mapid = no2_diff.clip(roi).getMapId(band_viz)

map = folium.Map(location=[24.11+10+3,75.27+46],zoom_start=4, height=550,width=600)

folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='AOD',
    opacity=0.2,
  ).add_to(map)

map.add_child(folium.LayerControl())
map.add_child(colormap)
#folium.map.LayerControl('topleft', collapsed=False).add_to(map)
title_html = '''
             <h3 align="center" style="font-size:20px"><b>AOD % change (2019-2020) </b></h3>
             '''
map.get_root().html.add_child(folium.Element(title_html))

map.save('aod_easia.html')
map
os.system("wkhtmltopdf --dpi 1000 aod_easia.html aod_easia.pdf")
os.system("pdfcrop --margins '0 0 0 0' aod_easia.pdf")
# Out:
# 0

# %%
collection20 = ee.ImageCollection('MODIS/006/MCD19A2_GRANULES').select('Optical_Depth_055').filterDate('2020-03-23', '2020-05-31').mean()
collection19 = ee.ImageCollection('MODIS/006/MCD19A2_GRANULES').select('Optical_Depth_055').filterDate('2019-03-23', '2019-05-31').mean()
no2_diff = collection19.subtract(collection20)
no2_diff = no2_diff.divide(collection19).multiply(100)
roi = ee.Geometry.Rectangle([65+30, 5-44, 98.5+90, 37-40])
band_viz = {
  'min': -50,
  'max': 50,
  #'palette': ['yellow', 'orange', 'red']
  'palette': ['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red']
}
colormap = cm.LinearColormap(['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red'], vmin=-50, vmax=50)
#colormap = cm.linear.YlOrRd_09.scale(0, 0.0002).to_step(10)
colormap.caption = '% change in aerosol optical depth'
no2_diff = collection19.subtract(collection20)
no2_diff = no2_diff.divide(collection19).multiply(100)
mapid = no2_diff.clip(roi).getMapId(band_viz)

map = folium.Map(location=[24.11-55,75.27+65],zoom_start=3.0, height=550,width=600)

folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='AOD',
    opacity=0.2,
  ).add_to(map)

map.add_child(folium.LayerControl())
map.add_child(colormap)
#folium.map.LayerControl('topleft', collapsed=False).add_to(map)
title_html = '''
             <h3 align="center" style="font-size:20px"><b>AOD % change (2019-2020) </b></h3>
             '''
map.get_root().html.add_child(folium.Element(title_html))

map.save('aod_aus.html')
map
os.system("wkhtmltopdf --dpi 1000 aod_aus.html aod_aus.pdf")
os.system("pdfcrop --margins '0 0 0 0' aod_aus.pdf")
# Out:
# 0

# %%
collection20 = ee.ImageCollection('MODIS/006/MCD19A2_GRANULES').select('Optical_Depth_055').filterDate('2020-03-13', '2020-05-31').mean()
collection19 = ee.ImageCollection('MODIS/006/MCD19A2_GRANULES').select('Optical_Depth_055').filterDate('2019-03-13', '2019-05-31').mean()
no2_diff = collection19.subtract(collection20)
no2_diff = no2_diff.divide(collection19).multiply(100)

roi = ee.Geometry.Rectangle([60-72, 5+30, 98.5+5-65, 37+23.5])
band_viz = {
  'min': -50,
  'max': 50,
  #'palette': ['yellow', 'orange', 'red']
  'palette': ['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red']
}
colormap = cm.LinearColormap(['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red'], vmin=-50, vmax=50)
#colormap = cm.linear.YlOrRd_09.scale(0, 0.0002).to_step(10)
colormap.caption = '% change in aerosol optical depth'
no2_diff = collection19.subtract(collection20)
no2_diff = no2_diff.divide(collection19).multiply(100)
mapid = no2_diff.clip(roi).getMapId(band_viz)

map = folium.Map(location=[24.11+27+4-1,75.27+5-67],zoom_start=3.8, height=550,width=600)

folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='AOD',
    opacity=0.2,
  ).add_to(map)

map.add_child(folium.LayerControl())
map.add_child(colormap)
#folium.map.LayerControl('topleft', collapsed=False).add_to(map)
title_html = '''
             <h3 align="center" style="font-size:20px"><b>AOD % change (2019-2020) </b></h3>
             '''
map.get_root().html.add_child(folium.Element(title_html))

map.save('aod_eu.html')
map
os.system("wkhtmltopdf --dpi 1000 aod_eu.html aod_eu.pdf")
os.system("pdfcrop --margins '0 0 0 0' aod_eu.pdf")
# Out:
# 0

# %%
collection20 = ee.ImageCollection('MODIS/006/MCD19A2_GRANULES').select('Optical_Depth_055').filterDate('2020-03-23', '2020-05-31').mean()
collection19 = ee.ImageCollection('MODIS/006/MCD19A2_GRANULES').select('Optical_Depth_055').filterDate('2019-03-23', '2019-05-31').mean()
no2_diff = collection19.subtract(collection20)
no2_diff = no2_diff.divide(collection19).multiply(100)

roi = ee.Geometry.Rectangle([60-200, 5+5, 98.5+5-150, 37+20])
band_viz = {
  'min': -50,
  'max': 50,
  #'palette': ['yellow', 'orange', 'red']
  'palette': ['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red']
}
colormap = cm.LinearColormap(['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red'], vmin=-50, vmax=50)
#colormap = cm.linear.YlOrRd_09.scale(0, 0.0002).to_step(10)
colormap.caption = '% change in aerosol optical depth'
no2_diff = collection19.subtract(collection20)
no2_diff = no2_diff.divide(collection19).multiply(100)
mapid = no2_diff.clip(roi).getMapId(band_viz)

map = folium.Map(location=[24.11+15+10,75.27+5-175],zoom_start=3.42, height=550,width=600)

folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='AOD',
    opacity=0.2,
  ).add_to(map)

map.add_child(folium.LayerControl())
map.add_child(colormap)
#folium.map.LayerControl('topleft', collapsed=False).add_to(map)
title_html = '''
             <h3 align="center" style="font-size:20px"><b>AOD % change (2019-2020) </b></h3>
             '''
map.get_root().html.add_child(folium.Element(title_html))

map.save('aod_na.html')
map
os.system("wkhtmltopdf --dpi 1000 aod_na.html aod_na.pdf")
os.system("pdfcrop --margins '0 0 0 0' aod_na.pdf")
# Out:
# 0

# %%
collection20 = ee.ImageCollection('MODIS/006/MCD19A2_GRANULES').select('Optical_Depth_055').filterDate('2020-03-13', '2020-05-31').mean()
collection19 = ee.ImageCollection('MODIS/006/MCD19A2_GRANULES').select('Optical_Depth_055').filterDate('2019-03-13', '2019-05-31').mean()
no2_diff = collection19.subtract(collection20)
no2_diff = no2_diff.divide(collection19).multiply(100)

roi = ee.Geometry.Rectangle([60-200+30, 5+5-53.5, 98.5+5-150+30, 37+20-50])
band_viz = {
  'min': -50,
  'max': 50,
  #'palette': ['yellow', 'orange', 'red']
  'palette': ['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red']
}
colormap = cm.LinearColormap(['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red'], vmin=-50, vmax=50)
#colormap = cm.linear.YlOrRd_09.scale(0, 0.0002).to_step(10)
colormap.caption = '% change in aerosol optical depth'
no2_diff = collection19.subtract(collection20)
no2_diff = no2_diff.divide(collection19).multiply(100)
mapid = no2_diff.clip(roi).getMapId(band_viz)

map = folium.Map(location=[24.11+15-67+6,75.27+5-175+30],zoom_start=3.42, height=550,width=600)

folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='AOD',
    opacity=0.2,
  ).add_to(map)

map.add_child(folium.LayerControl())
map.add_child(colormap)
#folium.map.LayerControl('topleft', collapsed=False).add_to(map)
title_html = '''
             <h3 align="center" style="font-size:20px"><b>AOD % change (2019-2020) </b></h3>
             '''
map.get_root().html.add_child(folium.Element(title_html))

map.save('aod_sa.html')
map
os.system("wkhtmltopdf --dpi 1000 aod_sa.html aod_sa.pdf")
os.system("pdfcrop --margins '0 0 0 0' aod_sa.pdf")
# Out:
# 0

# %%
collection20 = ee.ImageCollection('MODIS/006/MCD19A2_GRANULES').select('Optical_Depth_055').filterDate('2020-03-13', '2020-05-31').mean()
collection19 = ee.ImageCollection('MODIS/006/MCD19A2_GRANULES').select('Optical_Depth_055').filterDate('2019-03-13', '2019-05-31').mean()
no2_diff = collection19.subtract(collection20)
no2_diff = no2_diff.divide(collection19).multiply(100)

roi = ee.Geometry.Rectangle([60-100+20, 5+5-40, 98.5+5-50+60-45, 37+20-45+18])
band_viz = {
  'min': -50,
  'max': 50,
  #'palette': ['yellow', 'orange', 'red']
  'palette': ['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red']
}
colormap = cm.LinearColormap(['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red'], vmin=-50, vmax=50)
#colormap = cm.linear.YlOrRd_09.scale(0, 0.0002).to_step(10)
colormap.caption = '% change in aerosol optical depth'
no2_diff = collection19.subtract(collection20)
no2_diff = no2_diff.divide(collection19).multiply(100)
mapid = no2_diff.clip(roi).getMapId(band_viz)

map = folium.Map(location=[24.11+15-67+30+6,75.27+5-75+30-10],zoom_start=3.42, height=550,width=600)

folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='AOD',
    opacity=0.2,
  ).add_to(map)

map.add_child(folium.LayerControl())
map.add_child(colormap)
#folium.map.LayerControl('topleft', collapsed=False).add_to(map)
title_html = '''
             <h3 align="center" style="font-size:20px"><b>AOD % change (2019-2020) </b></h3>
             '''
map.get_root().html.add_child(folium.Element(title_html))

map.save('aod_af.html')
map
os.system("wkhtmltopdf --dpi 1000 aod_af.html aod_af.pdf")
os.system("pdfcrop --margins '0 0 0 0' aod_af.pdf")
# Out:
# 0

# %%
collection20 = ee.ImageCollection('COPERNICUS/S5P/OFFL/L3_NO2').select('tropospheric_NO2_column_number_density').filterDate('2020-03-23', '2020-06-30').mean()
collection19 = ee.ImageCollection('COPERNICUS/S5P/OFFL/L3_NO2').select('tropospheric_NO2_column_number_density').filterDate('2019-03-23', '2019-06-30').mean()
band_viz = {
  'min': 0,
  'max': 0.0002,
  #'palette': ['yellow', 'orange', 'red']
  'palette': ['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red']
}
roi = ee.Geometry.Rectangle([65, 5, 98.5, 37])

# %%
from cartopy.mpl.gridliner import LATITUDE_FORMATTER, LONGITUDE_FORMATTER
import matplotlib.pyplot as plt

import cartoee as cee
import cartopy.crs as ccrs

collection20 = ee.ImageCollection('COPERNICUS/S5P/OFFL/L3_NO2').select('tropospheric_NO2_column_number_density').filterDate('2020-03-13', '2020-05-31').mean()


srtm = ee.Image("CGIAR/SRTM90_V4")
# specify visualization parameters and region to map
visualization = {'min':0,'max':0.0002,'bands':'tropospheric_NO2_column_number_density'}
bbox = [-180,-90,180,90]

fig = plt.figure(figsize=(15,7))
ax = plt.subplot(projection=ccrs.PlateCarree())
cee.addLayer(collection20,ax=ax, cmap=plt.cm.terrain,visParams=visualization,dims=2000)

# # plot the map
# #ax = cee.getMap(srtm,cmap='terrain',region=bbox,visParams=visualization,dims=4000)
# # add a color bar using cartoee
# #cb = cee.addColorbar(ax,loc='right',cmap=matplotlib.colors.Colormap('terrain'),visParams=visualization)
cb = cee.addColorbar(ax,loc='right',cmap=plt.cm.terrain,visParams=visualization)

ax.coastlines()

# # set gridlines and spacing
xticks = [-180,-120,-60,0,60,120,180]
yticks = [-90,-60,-30,0,30,60,90]
ax.gridlines(xlocs=xticks, ylocs=yticks,linestyle='--')

# # set custom formatting for the tick labels
ax.xaxis.set_major_formatter(LONGITUDE_FORMATTER)
ax.yaxis.set_major_formatter(LATITUDE_FORMATTER)

# set tick labels
ax.set_xticks([-180,-120,-60, 0, 60, 120, 180], crs=ccrs.PlateCarree())
ax.set_yticks([-90, -60, -30, 0, 30, 60, 90], crs=ccrs.PlateCarree())

# plt.savefig('test.png')
# Out:
# /home/manmeet/anaconda3/envs/py36/lib/python3.6/site-packages/cartopy/mpl/geoaxes.py:773: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   return super(GeoAxes, self).set_xticks(xticks, minor)
# /home/manmeet/anaconda3/envs/py36/lib/python3.6/site-packages/cartopy/mpl/geoaxes.py:820: MatplotlibDeprecationWarning: Passing the minor parameter of set_yticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   return super(GeoAxes, self).set_yticks(yticks, minor)
# [<matplotlib.axis.YTick at 0x7fc978265f60>,
#  <matplotlib.axis.YTick at 0x7fc978265940>,
#  <matplotlib.axis.YTick at 0x7fc978261cf8>,
#  <matplotlib.axis.YTick at 0x7fc978155240>,
#  <matplotlib.axis.YTick at 0x7fc9781556d8>,
#  <matplotlib.axis.YTick at 0x7fc978155b70>,
#  <matplotlib.axis.YTick at 0x7fc97815f0b8>]

# %%
# collection20 = ee.ImageCollection('MODIS/006/MCD19A2_GRANULES').select('Optical_Depth_055').filterDate('2020-03-23', '2020-05-31').mean()

# visualization = {'min':0,'max':500,'bands':'Optical_Depth_055'}
# bbox = [-180,-90,180,90]
# bbox = [65+30, 5+10, 98.5+50, 37+10]

# fig = plt.figure(figsize=(15,7))
# ax = plt.subplot(projection=ccrs.PlateCarree())
# cee.addLayer(collection20,ax=ax, cmap=plt.cm.terrain,visParams=visualization,dims=2000, region=bbox)

# # # plot the map
# # #ax = cee.getMap(srtm,cmap='terrain',region=bbox,visParams=visualization,dims=4000)
# # # add a color bar using cartoee
# # #cb = cee.addColorbar(ax,loc='right',cmap=matplotlib.colors.Colormap('terrain'),visParams=visualization)
# cb = cee.addColorbar(ax,loc='right',cmap=plt.cm.terrain,visParams=visualization)

# ax.coastlines()

# # # set gridlines and spacing
# xticks = [-180,-120,-60,0,60,120,180]
# yticks = [-90,-60,-30,0,30,60,90]
# ax.gridlines(xlocs=xticks, ylocs=yticks,linestyle='--')

# # # set custom formatting for the tick labels
# ax.xaxis.set_major_formatter(LONGITUDE_FORMATTER)
# ax.yaxis.set_major_formatter(LATITUDE_FORMATTER)

# # set tick labels
# ax.set_xticks([-180,-120,-60, 0, 60, 120, 180], crs=ccrs.PlateCarree())
# ax.set_yticks([-90, -60, -30, 0, 30, 60, 90], crs=ccrs.PlateCarree())

# # plt.savefig('test.png')

# %%
# fig = plt.figure(figsize=(15,7))
# ax = plt.subplot(projection=ccrs.PlateCarree())
# cee.addLayer(collection20,ax=ax, cmap=plt.cm.terrain,visParams=visualization,dims=2000)
