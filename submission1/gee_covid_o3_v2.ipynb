# %%
from IPython.display import Image
import ee, folium
import os
#import folium.colormap as cm
import branca
import branca.colormap as cm
ee.Initialize()
print (folium.__file__)
print (folium.__version__)
# Out:
# /home/manmeet/anaconda3/envs/py36/lib/python3.6/site-packages/folium/__init__.py
# 0.11.0

# %%
collection20 = ee.ImageCollection('COPERNICUS/S5P/OFFL/L3_O3_TCL').select('ozone_tropospheric_vertical_column').filterDate('2020-03-23', '2020-05-31').mean()
collection19 = ee.ImageCollection('COPERNICUS/S5P/OFFL/L3_O3_TCL').select('ozone_tropospheric_vertical_column').filterDate('2019-03-23', '2019-05-31').mean()

# mask = collection20.lt(0.0)
# mask_ = collection20.gt(0.0)
# value = 0.0
# collection20 = mask.multiply(value).add(collection20.multiply(mask_))

# mask = collection19.lt(0)
# mask_ = collection19.gt(0)
# value = 0.0
# collection19 = mask.multiply(value).add(collection19.multiply(mask_))


no2_diff = collection19.subtract(collection20)
no2_diff = no2_diff.divide(collection19).multiply(100)

roi = ee.Geometry.Rectangle([60, 5, 98.5+5, 37])
band_viz = {
  'min': -50,
  'max': 50,
  #'palette': ['yellow', 'orange', 'red']
  'palette': ['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red']
}
colormap = cm.LinearColormap(['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red'], vmin=-50, vmax=50)
#colormap = cm.linear.YlOrRd_09.scale(0, 0.0002).to_step(10)
colormap.caption = '% change in mixing ratio'
no2_diff = collection19.subtract(collection20)
no2_diff = no2_diff.divide(collection19).multiply(100)
mapid = no2_diff.clip(roi).getMapId(band_viz)

map = folium.Map(location=[24.11+2,75.27+5],zoom_start=4, height=550,width=600)

folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='O3',
    opacity=0.2,
  ).add_to(map)

map.add_child(folium.LayerControl())
map.add_child(colormap)
#folium.map.LayerControl('topleft', collapsed=False).add_to(map)
title_html = '''
             <h3 align="center" style="font-size:20px"><b>O3 % change (2019-2020) </b></h3>
             '''
map.get_root().html.add_child(folium.Element(title_html))

map.save('o3_india.html')
map
os.system("wkhtmltopdf --dpi 1000 o3_india.html o3_india.pdf")
os.system("pdfcrop --margins '0 0 0 0' o3_india.pdf")
# Out:
# 0

# %%
collection20 = ee.ImageCollection('COPERNICUS/S5P/OFFL/L3_O3_TCL').select('ozone_tropospheric_vertical_column').filterDate('2020-03-23', '2020-05-31').mean()
collection19 = ee.ImageCollection('COPERNICUS/S5P/OFFL/L3_O3_TCL').select('ozone_tropospheric_vertical_column').filterDate('2019-03-23', '2019-05-31').mean()

# mask = collection20.lt(-0.001)
# mask_ = collection20.gt(-0.001)
# value = 0.0
# collection20 = mask.multiply(value).add(collection20.multiply(mask_))

# mask = collection19.lt(0)
# mask_ = collection19.gt(0)
# value = 0.0
# collection19 = mask.multiply(value).add(collection19.multiply(mask_))


no2_diff = collection19.subtract(collection20)
no2_diff = no2_diff.divide(collection19).multiply(100)

roi = ee.Geometry.Rectangle([65+30, 5-15, 98.5+40, 37-15])
band_viz = {
  'min': -50,
  'max': 50,
  #'palette': ['yellow', 'orange', 'red']
  'palette': ['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red']
}
colormap = cm.LinearColormap(['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red'], vmin=-50, vmax=50)
#colormap = cm.linear.YlOrRd_09.scale(0, 0.0002).to_step(10)
colormap.caption = '% change in mixing ratio'
no2_diff = collection19.subtract(collection20)
no2_diff = no2_diff.divide(collection19).multiply(100)
mapid = no2_diff.clip(roi).getMapId(band_viz)

map = folium.Map(location=[24.11-15,75.27+40],zoom_start=4, height=550,width=600)

folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='O3',
    opacity=0.2,
  ).add_to(map)

map.add_child(folium.LayerControl())
map.add_child(colormap)
#folium.map.LayerControl('topleft', collapsed=False).add_to(map)
title_html = '''
             <h3 align="center" style="font-size:20px"><b>O3 % change (2019-2020) </b></h3>
             '''
map.get_root().html.add_child(folium.Element(title_html))

map.save('o3_seasia.html')
map
os.system("wkhtmltopdf --dpi 1000 o3_seasia.html o3_seasia.pdf")
os.system("pdfcrop --margins '0 0 0 0' o3_seasia.pdf")
# Out:
# 0

# %%
collection20 = ee.ImageCollection('COPERNICUS/S5P/OFFL/L3_O3_TCL').select('ozone_tropospheric_vertical_column').filterDate('2020-01-24', '2020-03-25').mean()
collection19 = ee.ImageCollection('COPERNICUS/S5P/OFFL/L3_O3_TCL').select('ozone_tropospheric_vertical_column').filterDate('2019-01-24', '2019-03-25').mean()

# mask = collection20.lt(-0.001)
# mask_ = collection20.gt(-0.001)
# value = 0.0
# collection20 = mask.multiply(value).add(collection20.multiply(mask_))

# mask = collection19.lt(0)
# mask_ = collection19.gt(0)
# value = 0.0
# collection19 = mask.multiply(value).add(collection19.multiply(mask_))


no2_diff = collection19.subtract(collection20)
no2_diff = no2_diff.divide(collection19).multiply(100)
roi = ee.Geometry.Rectangle([65+30, 5+10, 98.5+50, 37+10-2])
band_viz = {
  'min': -50,
  'max': 50,
  #'palette': ['yellow', 'orange', 'red']
  'palette': ['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red']
}
colormap = cm.LinearColormap(['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red'], vmin=-50, vmax=50)
#colormap = cm.linear.YlOrRd_09.scale(0, 0.0002).to_step(10)
colormap.caption = '% change in mixing ratio'
no2_diff = collection19.subtract(collection20)
no2_diff = no2_diff.divide(collection19).multiply(100)
mapid = no2_diff.clip(roi).getMapId(band_viz)

map = folium.Map(location=[24.11+10+3,75.27+46],zoom_start=4, height=550,width=600)

folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='O3',
    opacity=0.2,
  ).add_to(map)

map.add_child(folium.LayerControl())
map.add_child(colormap)
#folium.map.LayerControl('topleft', collapsed=False).add_to(map)
title_html = '''
             <h3 align="center" style="font-size:20px"><b>O3 % change (2019-2020) </b></h3>
             '''
map.get_root().html.add_child(folium.Element(title_html))

map.save('o3_easia.html')
map
os.system("wkhtmltopdf --dpi 1000 o3_easia.html o3_easia.pdf")
os.system("pdfcrop --margins '0 0 0 0' o3_easia.pdf")
# Out:
# 0

# %%
collection20 = ee.ImageCollection('COPERNICUS/S5P/OFFL/L3_O3_TCL').select('ozone_tropospheric_vertical_column').filterDate('2020-03-23', '2020-05-31').mean()
collection19 = ee.ImageCollection('COPERNICUS/S5P/OFFL/L3_O3_TCL').select('ozone_tropospheric_vertical_column').filterDate('2019-03-23', '2019-05-31').mean()

# mask = collection20.lt(-0.001)
# mask_ = collection20.gt(-0.001)
# value = 0.0
# collection20 = mask.multiply(value).add(collection20.multiply(mask_))

# mask = collection19.lt(0)
# mask_ = collection19.gt(0)
# value = 0.0
# collection19 = mask.multiply(value).add(collection19.multiply(mask_))


no2_diff = collection19.subtract(collection20)
no2_diff = no2_diff.divide(collection19).multiply(100)
roi = ee.Geometry.Rectangle([65+30, 5-44, 98.5+90, 37-40])
band_viz = {
  'min': -50,
  'max': 50,
  #'palette': ['yellow', 'orange', 'red']
  'palette': ['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red']
}
colormap = cm.LinearColormap(['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red'], vmin=-50, vmax=50)
#colormap = cm.linear.YlOrRd_09.scale(0, 0.0002).to_step(10)
colormap.caption = '% change in mixing ratio'
no2_diff = collection19.subtract(collection20)
no2_diff = no2_diff.divide(collection19).multiply(100)
mapid = no2_diff.clip(roi).getMapId(band_viz)

map = folium.Map(location=[24.11-55,75.27+65],zoom_start=3.0, height=550,width=600)

folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='O3',
    opacity=0.2,
  ).add_to(map)

map.add_child(folium.LayerControl())
map.add_child(colormap)
#folium.map.LayerControl('topleft', collapsed=False).add_to(map)
title_html = '''
             <h3 align="center" style="font-size:20px"><b>O3 % change (2019-2020) </b></h3>
             '''
map.get_root().html.add_child(folium.Element(title_html))

map.save('o3_aus.html')
map
os.system("wkhtmltopdf --dpi 1000 o3_aus.html o3_aus.pdf")
os.system("pdfcrop --margins '0 0 0 0' o3_aus.pdf")
# Out:
# 0

# %%
collection20 = ee.ImageCollection('COPERNICUS/S5P/OFFL/L3_O3_TCL').select('ozone_tropospheric_vertical_column').filterDate('2020-03-13', '2020-05-31').mean()
collection19 = ee.ImageCollection('COPERNICUS/S5P/OFFL/L3_O3_TCL').select('ozone_tropospheric_vertical_column').filterDate('2019-03-13', '2019-05-31').mean()

# mask = collection20.lt(-0.001)
# mask_ = collection20.gt(-0.001)
# value = 0.0
# collection20 = mask.multiply(value).add(collection20.multiply(mask_))

# mask = collection19.lt(0)
# mask_ = collection19.gt(0)
# value = 0.0
# collection19 = mask.multiply(value).add(collection19.multiply(mask_))


no2_diff = collection19.subtract(collection20)
no2_diff = no2_diff.divide(collection19).multiply(100)

roi = ee.Geometry.Rectangle([60-72, 5+30, 98.5+5-65, 37+23.5])
band_viz = {
  'min': -50,
  'max': 50,
  #'palette': ['yellow', 'orange', 'red']
  'palette': ['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red']
}
colormap = cm.LinearColormap(['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red'], vmin=-50, vmax=50)
#colormap = cm.linear.YlOrRd_09.scale(0, 0.0002).to_step(10)
colormap.caption = '% change in mixing ratio'
no2_diff = collection19.subtract(collection20)
no2_diff = no2_diff.divide(collection19).multiply(100)
mapid = no2_diff.clip(roi).getMapId(band_viz)

map = folium.Map(location=[24.11+27+4-1,75.27+5-67],zoom_start=3.8, height=550,width=600)

folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='O3',
    opacity=0.2,
  ).add_to(map)

map.add_child(folium.LayerControl())
map.add_child(colormap)
#folium.map.LayerControl('topleft', collapsed=False).add_to(map)
title_html = '''
             <h3 align="center" style="font-size:20px"><b>O3 % change (2019-2020) </b></h3>
             '''
map.get_root().html.add_child(folium.Element(title_html))

map.save('o3_eu.html')
map
os.system("wkhtmltopdf --dpi 1000 o3_eu.html o3_eu.pdf")
os.system("pdfcrop --margins '0 0 0 0' o3_eu.pdf")
# Out:
# 0

# %%
collection20 = ee.ImageCollection('COPERNICUS/S5P/OFFL/L3_O3_TCL').select('ozone_tropospheric_vertical_column').filterDate('2020-03-23', '2020-05-31').mean()
collection19 = ee.ImageCollection('COPERNICUS/S5P/OFFL/L3_O3_TCL').select('ozone_tropospheric_vertical_column').filterDate('2019-03-23', '2019-05-31').mean()

# mask = collection20.lt(-0.001)
# mask_ = collection20.gt(-0.001)
# value = 0.0
# collection20 = mask.multiply(value).add(collection20.multiply(mask_))

# mask = collection19.lt(0)
# mask_ = collection19.gt(0)
# value = 0.0
# collection19 = mask.multiply(value).add(collection19.multiply(mask_))


no2_diff = collection19.subtract(collection20)
no2_diff = no2_diff.divide(collection19).multiply(100)

roi = ee.Geometry.Rectangle([60-200, 5+5, 98.5+5-150, 37+20])
band_viz = {
  'min': -50,
  'max': 50,
  #'palette': ['yellow', 'orange', 'red']
  'palette': ['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red']
}
colormap = cm.LinearColormap(['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red'], vmin=-50, vmax=50)
#colormap = cm.linear.YlOrRd_09.scale(0, 0.0002).to_step(10)
colormap.caption = '% change in mixing ratio'
no2_diff = collection19.subtract(collection20)
no2_diff = no2_diff.divide(collection19).multiply(100)
mapid = no2_diff.clip(roi).getMapId(band_viz)

map = folium.Map(location=[24.11+15+10,75.27+5-175],zoom_start=3.42, height=550,width=600)

folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='O3',
    opacity=0.2,
  ).add_to(map)

map.add_child(folium.LayerControl())
map.add_child(colormap)
#folium.map.LayerControl('topleft', collapsed=False).add_to(map)
title_html = '''
             <h3 align="center" style="font-size:20px"><b>O3 % change (2019-2020) </b></h3>
             '''
map.get_root().html.add_child(folium.Element(title_html))

map.save('o3_na.html')
map
os.system("wkhtmltopdf --dpi 1000 o3_na.html o3_na.pdf")
os.system("pdfcrop --margins '0 0 0 0' o3_na.pdf")
# Out:
# 0

# %%
collection20 = ee.ImageCollection('COPERNICUS/S5P/OFFL/L3_O3_TCL').select('ozone_tropospheric_vertical_column').filterDate('2020-03-13', '2020-05-31').mean()
collection19 = ee.ImageCollection('COPERNICUS/S5P/OFFL/L3_O3_TCL').select('ozone_tropospheric_vertical_column').filterDate('2019-03-13', '2019-05-31').mean()

# mask = collection20.lt(-0.001)
# mask_ = collection20.gt(-0.001)
# value = 0.0
# collection20 = mask.multiply(value).add(collection20.multiply(mask_))

# mask = collection19.lt(0)
# mask_ = collection19.gt(0)
# value = 0.0
# collection19 = mask.multiply(value).add(collection19.multiply(mask_))

no2_diff = collection19.subtract(collection20)
no2_diff = no2_diff.divide(collection19).multiply(100)

roi = ee.Geometry.Rectangle([60-200+30, 5+5-53.5, 98.5+5-150+30, 37+20-50])
band_viz = {
  'min': -50,
  'max': 50,
  #'palette': ['yellow', 'orange', 'red']
  'palette': ['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red']
}
colormap = cm.LinearColormap(['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red'], vmin=-50, vmax=50)
#colormap = cm.linear.YlOrRd_09.scale(0, 0.0002).to_step(10)
colormap.caption = '% change in mixing ratio'
no2_diff = collection19.subtract(collection20)
no2_diff = no2_diff.divide(collection19).multiply(100)
mapid = no2_diff.clip(roi).getMapId(band_viz)

map = folium.Map(location=[24.11+15-67+6,75.27+5-175+30],zoom_start=3.42, height=550,width=600)

folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='O3',
    opacity=0.2,
  ).add_to(map)

map.add_child(folium.LayerControl())
map.add_child(colormap)
#folium.map.LayerControl('topleft', collapsed=False).add_to(map)
title_html = '''
             <h3 align="center" style="font-size:20px"><b>O3 % change (2019-2020) </b></h3>
             '''
map.get_root().html.add_child(folium.Element(title_html))

map.save('o3_sa.html')
map
os.system("wkhtmltopdf --dpi 1000 o3_sa.html o3_sa.pdf")
os.system("pdfcrop --margins '0 0 0 0' o3_sa.pdf")
# Out:
# 0

# %%
collection20 = ee.ImageCollection('COPERNICUS/S5P/OFFL/L3_O3_TCL').select('ozone_tropospheric_vertical_column').filterDate('2020-03-13', '2020-05-31').mean()
collection19 = ee.ImageCollection('COPERNICUS/S5P/OFFL/L3_O3_TCL').select('ozone_tropospheric_vertical_column').filterDate('2019-03-13', '2019-05-31').mean()

# mask = collection20.lt(-0.001)
# mask_ = collection20.gt(-0.001)
# value = 0.0
# collection20 = mask.multiply(value).add(collection20.multiply(mask_))

# mask = collection19.lt(0)
# mask_ = collection19.gt(0)
# value = 0.0
# collection19 = mask.multiply(value).add(collection19.multiply(mask_))


no2_diff = collection19.subtract(collection20)
no2_diff = no2_diff.divide(collection19).multiply(100)

roi = ee.Geometry.Rectangle([60-100+20, 5+5-40, 98.5+5-50+60-45, 37+20-45+18])
band_viz = {
  'min': -50,
  'max': 50,
  #'palette': ['yellow', 'orange', 'red']
  'palette': ['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red']
}
colormap = cm.LinearColormap(['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red'], vmin=-50, vmax=50)
#colormap = cm.linear.YlOrRd_09.scale(0, 0.0002).to_step(10)
colormap.caption = '% change in mixing ratio'
no2_diff = collection19.subtract(collection20)
no2_diff = no2_diff.divide(collection19).multiply(100)
mapid = no2_diff.clip(roi).getMapId(band_viz)

map = folium.Map(location=[24.11+15-67+30+6,75.27+5-75+30-10],zoom_start=3.42, height=550,width=600)

folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='O3',
    opacity=0.2,
  ).add_to(map)

map.add_child(folium.LayerControl())
map.add_child(colormap)
#folium.map.LayerControl('topleft', collapsed=False).add_to(map)
title_html = '''
             <h3 align="center" style="font-size:20px"><b>O3 % change (2019-2020) </b></h3>
             '''
map.get_root().html.add_child(folium.Element(title_html))

map.save('o3_af.html')
map
os.system("wkhtmltopdf --dpi 1000 o3_af.html o3_af.pdf")
os.system("pdfcrop --margins '0 0 0 0' o3_af.pdf")
# Out:
# 0
