# %%
from IPython.display import Image
import ee, folium
#import folium.colormap as cm
import branca
import branca.colormap as cm
ee.Initialize()
print (folium.__file__)
print (folium.__version__)
# Out:
# /home/manmeet/anaconda3/envs/py36/lib/python3.6/site-packages/folium/__init__.py
# 0.11.0

# %%
collection20 = ee.ImageCollection('COPERNICUS/S5P/OFFL/L3_O3_TCL').select('ozone_tropospheric_vertical_column').filterDate('2020-03-23', '2020-06-30').mean()
collection19 = ee.ImageCollection('COPERNICUS/S5P/OFFL/L3_O3_TCL').select('ozone_tropospheric_vertical_column').filterDate('2020-02-22', '2020-03-22').mean()
band_viz = {
  'min': 0.0,
  'max': 0.02,
  #'palette': ['yellow', 'orange', 'red']
  'palette': ['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red']
}
roi = ee.Geometry.Rectangle([65, 5, 98.5, 37])

# %%
colormap = cm.LinearColormap(['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red'], vmin=0.0, vmax=0.02)
#colormap = cm.linear.YlOrRd_09.scale(0, 0.0002).to_step(10)
colormap.caption = 'O3'
no2_diff = collection20.subtract(collection19)
#no2_diff = no2_diff.divide(collection19)
mapid = collection20.clip(roi).getMapId(band_viz)

map = folium.Map(location=[24.11,75.27],zoom_start=4, height=550,width=600)

folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='O3',
    opacity=0.5,
  ).add_to(map)

map.add_child(folium.LayerControl())
map.add_child(colormap)
#folium.map.LayerControl('topleft', collapsed=False).add_to(map)
title_html = '''
             <h3 align="center" style="font-size:20px"><b>O3 2020</b></h3>
             '''
map.get_root().html.add_child(folium.Element(title_html))
map.save('plot_data.html')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
colormap = cm.LinearColormap(['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red'], vmin=0, vmax=0.02)
#colormap = cm.linear.YlOrRd_09.scale(0, 0.0002).to_step(10)
colormap.caption = 'O3'
no2_diff = collection19.subtract(collection19)
#no2_diff = no2_diff.divide(collection19)
mapid = collection20.clip(roi).getMapId(band_viz)

map = folium.Map(location=[24.11,75.27],zoom_start=4, height=550,width=600)

folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='O3',
    opacity=0.5,
  ).add_to(map)

map.add_child(folium.LayerControl())
map.add_child(colormap)
#folium.map.LayerControl('topleft', collapsed=False).add_to(map)
title_html = '''
             <h3 align="center" style="font-size:20px"><b>O3 2019</b></h3>
             '''
map.get_root().html.add_child(folium.Element(title_html))

map.save('plot_data.html')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
band_viz = {
  'min': -0.002,
  'max': 0.002,
  #'palette': ['yellow', 'orange', 'red']
  'palette': ['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red']
}
colormap = cm.LinearColormap(['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red'], vmin=-0.002, vmax=0.002)
#colormap = cm.linear.YlOrRd_09.scale(0, 0.0002).to_step(10)
colormap.caption = 'O3'
no2_diff = collection19.subtract(collection20)
#no2_diff = no2_diff.divide(collection19)
mapid = no2_diff.clip(roi).getMapId(band_viz)

map = folium.Map(location=[24.11,75.27],zoom_start=4, height=550,width=600)

folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='O3',
    opacity=0.5,
  ).add_to(map)

map.add_child(folium.LayerControl())
map.add_child(colormap)
#folium.map.LayerControl('topleft', collapsed=False).add_to(map)
title_html = '''
             <h3 align="center" style="font-size:20px"><b>O3 (2019) - O3 (2020)</b></h3>
             '''
map.get_root().html.add_child(folium.Element(title_html))

map.save('plot_data.html')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
band_viz = {
  'min': -10,
  'max': 10,
  #'palette': ['yellow', 'orange', 'red']
  'palette': ['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red']
}
colormap = cm.LinearColormap(['black', 'blue', 'purple', 'cyan', 'green', 'yellow', 'red'], vmin=-5, vmax=5)
#colormap = cm.linear.YlOrRd_09.scale(0, 0.0002).to_step(10)
colormap.caption = '% change in column number density'
no2_diff = collection19.subtract(collection20)
no2_diff = no2_diff.divide(collection19).multiply(100)
mapid = no2_diff.clip(roi).getMapId(band_viz)

map = folium.Map(location=[24.11,75.27],zoom_start=4, height=550,width=600)

folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='O3',
    opacity=0.5,
  ).add_to(map)

map.add_child(folium.LayerControl())
map.add_child(colormap)
#folium.map.LayerControl('topleft', collapsed=False).add_to(map)
title_html = '''
             <h3 align="center" style="font-size:20px"><b>O3 % change (2019-2020) </b></h3>
             '''
map.get_root().html.add_child(folium.Element(title_html))

map.save('plot_data.html')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
