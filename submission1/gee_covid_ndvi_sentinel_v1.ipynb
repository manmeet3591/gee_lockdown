# %%
from IPython.display import Image
import ee, folium
#import folium.colormap as cm
import branca
import branca.colormap as cm
ee.Initialize()
print (folium.__file__)
print (folium.__version__)
# Out:
# /home/manmeet/anaconda3/envs/py36/lib/python3.6/site-packages/folium/__init__.py
# 0.11.0

# %%
collection20_b5 = ee.ImageCollection('COPERNICUS/S2').select('B8').filterDate('2020-03-23', '2020-05-31').filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 50)).mean()
collection20_b4 = ee.ImageCollection('COPERNICUS/S2').select('B4').filterDate('2020-03-23', '2020-05-31').filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 50)).mean()
ndvi20 = collection20_b5.subtract(collection20_b4).divide(collection20_b5.add(collection20_b4)).rename('NDVI')

collection19_b5 = ee.ImageCollection('COPERNICUS/S2').select('B8').filterDate('2019-03-23', '2019-05-31').filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 50)).mean()
collection19_b4 = ee.ImageCollection('COPERNICUS/S2').select('B4').filterDate('2019-03-23', '2019-05-31').filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 50)).mean()
ndvi19 = collection19_b5.subtract(collection19_b4).divide(collection19_b5.add(collection19_b4)).rename('NDVI')

no2_diff = ndvi19.subtract(ndvi20)
no2_diff = no2_diff.divide(ndvi19).multiply(100)


roi = ee.Geometry.Rectangle([60, 5, 98.5+5, 37])
band_viz = {
  'min': -100,
  'max': 100,
  #'palette': ['yellow', 'orange', 'red']
  'palette': ['green','white', 'blue']
}
colormap = cm.LinearColormap(['green','white', 'blue'], vmin=-100, vmax=100)
#colormap = cm.linear.YlOrRd_09.scale(0, 0.0002).to_step(10)
colormap.caption = '% change in NDVI'
# no2_diff = collection19.subtract(collection20)
# no2_diff = no2_diff.divide(collection19).multiply(100)
mapid = no2_diff.clip(roi).getMapId(band_viz)

map = folium.Map(location=[24.11,75.27+5],zoom_start=4, height=550,width=600)

folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='NDVI',
    opacity=0.45,
  ).add_to(map)

map.add_child(folium.LayerControl())
map.add_child(colormap)
#folium.map.LayerControl('topleft', collapsed=False).add_to(map)
title_html = '''
             <h3 align="center" style="font-size:20px"><b>NDVI % change (2019-2020) </b></h3>
             '''
map.get_root().html.add_child(folium.Element(title_html))

map.save('ndvi_india.html')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
collection20_b5 = ee.ImageCollection('LANDSAT/LC08/C01/T1_TOA').select('B5').filterDate('2020-03-23', '2020-05-31').mean()
collection20_b4 = ee.ImageCollection('LANDSAT/LC08/C01/T1_TOA').select('B4').filterDate('2020-03-23', '2020-05-31').mean()
ndvi20 = collection20_b5.subtract(collection20_b4).divide(collection20_b5.add(collection20_b4)).rename('NDVI')

collection19_b5 = ee.ImageCollection('LANDSAT/LC08/C01/T1_TOA').select('B5').filterDate('2019-03-23', '2019-05-31').mean()
collection19_b4 = ee.ImageCollection('LANDSAT/LC08/C01/T1_TOA').select('B4').filterDate('2019-03-23', '2019-05-31').mean()
ndvi19 = collection19_b5.subtract(collection19_b4).divide(collection19_b5.add(collection19_b4)).rename('NDVI')

no2_diff = ndvi19.subtract(ndvi20)
no2_diff = no2_diff.divide(ndvi19).multiply(100)



roi = ee.Geometry.Rectangle([65+30, 5-15, 98.5+40, 37-15])
band_viz = {
  'min': -100,
  'max': 100,
  #'palette': ['yellow', 'orange', 'red']
  'palette': ['green','white', 'blue']
}
colormap = cm.LinearColormap(['green','white', 'blue'], vmin=-100, vmax=100)
#colormap = cm.linear.YlOrRd_09.scale(0, 0.0002).to_step(10)
colormap.caption = '% change in NDVI'
# no2_diff = collection19.subtract(collection20)
# no2_diff = no2_diff.divide(collection19).multiply(100)
mapid = no2_diff.clip(roi).getMapId(band_viz)

map = folium.Map(location=[24.11-15,75.27+40],zoom_start=4, height=550,width=600)

folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='NDVI',
    opacity=0.3,
  ).add_to(map)

map.add_child(folium.LayerControl())
map.add_child(colormap)
#folium.map.LayerControl('topleft', collapsed=False).add_to(map)
title_html = '''
             <h3 align="center" style="font-size:20px"><b>NDVI % change (2019-2020) </b></h3>
             '''
map.get_root().html.add_child(folium.Element(title_html))

map.save('ndvi_seasia.html')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
collection20_b5 = ee.ImageCollection('LANDSAT/LC08/C01/T1_TOA').select('B5').filterDate('2020-01-24', '2020-03-25').mean()
collection20_b4 = ee.ImageCollection('LANDSAT/LC08/C01/T1_TOA').select('B4').filterDate('2020-01-24', '2020-03-25').mean()
ndvi20 = collection20_b5.subtract(collection20_b4).divide(collection20_b5.add(collection20_b4)).rename('NDVI')

collection19_b5 = ee.ImageCollection('LANDSAT/LC08/C01/T1_TOA').select('B5').filterDate('2019-01-24', '2019-03-25').mean()
collection19_b4 = ee.ImageCollection('LANDSAT/LC08/C01/T1_TOA').select('B4').filterDate('2019-01-24', '2019-03-25').mean()
ndvi19 = collection19_b5.subtract(collection19_b4).divide(collection19_b5.add(collection19_b4)).rename('NDVI')

no2_diff = ndvi19.subtract(ndvi20)
no2_diff = no2_diff.divide(ndvi19).multiply(100)


roi = ee.Geometry.Rectangle([65+30, 5+10, 98.5+50, 37+10])
band_viz = {
  'min': -100,
  'max': 100,
  #'palette': ['yellow', 'orange', 'red']
  'palette': ['green','white', 'blue']
}
colormap = cm.LinearColormap(['green','white', 'blue'], vmin=-100, vmax=100)
#colormap = cm.linear.YlOrRd_09.scale(0, 0.0002).to_step(10)
colormap.caption = '% change in NDVI'
# no2_diff = collection19.subtract(collection20)
# no2_diff = no2_diff.divide(collection19).multiply(100)
mapid = no2_diff.clip(roi).getMapId(band_viz)

map = folium.Map(location=[24.11+10,75.27+46],zoom_start=4, height=550,width=600)

folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='NDVI',
    opacity=0.3,
  ).add_to(map)

map.add_child(folium.LayerControl())
map.add_child(colormap)
#folium.map.LayerControl('topleft', collapsed=False).add_to(map)
title_html = '''
             <h3 align="center" style="font-size:20px"><b>NDVI % change (2019-2020) </b></h3>
             '''
map.get_root().html.add_child(folium.Element(title_html))

map.save('ndvi_easia.html')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
collection20_b5 = ee.ImageCollection('LANDSAT/LC08/C01/T1_TOA').select('B5').filterDate('2020-03-23', '2020-05-31').mean()
collection20_b4 = ee.ImageCollection('LANDSAT/LC08/C01/T1_TOA').select('B4').filterDate('2020-03-23', '2020-05-31').mean()
ndvi20 = collection20_b5.subtract(collection20_b4).divide(collection20_b5.add(collection20_b4)).rename('NDVI')

collection19_b5 = ee.ImageCollection('LANDSAT/LC08/C01/T1_TOA').select('B5').filterDate('2019-03-23', '2019-05-31').mean()
collection19_b4 = ee.ImageCollection('LANDSAT/LC08/C01/T1_TOA').select('B4').filterDate('2019-03-23', '2019-05-31').mean()
ndvi19 = collection19_b5.subtract(collection19_b4).divide(collection19_b5.add(collection19_b4)).rename('NDVI')

no2_diff = ndvi19.subtract(ndvi20)
no2_diff = no2_diff.divide(ndvi19).multiply(100)



roi = ee.Geometry.Rectangle([65+30, 5-44, 98.5+90, 37-40])
band_viz = {
  'min': -50,
  'max': 50,
  #'palette': ['yellow', 'orange', 'red']
  'palette': ['blue', 'white', 'green']
}
colormap = cm.LinearColormap(['green','white', 'blue'], vmin=-50, vmax=50)
#colormap = cm.linear.YlOrRd_09.scale(0, 0.0002).to_step(10)
colormap.caption = '% change in NDVI'
# no2_diff = collection19.subtract(collection20)
# no2_diff = no2_diff.divide(collection19).multiply(100)
mapid = no2_diff.clip(roi).getMapId(band_viz)

map = folium.Map(location=[24.11-55,75.27+65],zoom_start=3.0, height=550,width=600)

folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='NDVI',
    opacity=0.3,
  ).add_to(map)

map.add_child(folium.LayerControl())
map.add_child(colormap)
#folium.map.LayerControl('topleft', collapsed=False).add_to(map)
title_html = '''
             <h3 align="center" style="font-size:20px"><b>NDVI % change (2019-2020) </b></h3>
             '''
map.get_root().html.add_child(folium.Element(title_html))

map.save('ndvi_aus.html')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
collection20_b5 = ee.ImageCollection('LANDSAT/LC08/C01/T1_TOA').select('B5').filterDate('2020-03-13', '2020-05-31').mean()
collection20_b4 = ee.ImageCollection('LANDSAT/LC08/C01/T1_TOA').select('B4').filterDate('2020-03-13', '2020-05-31').mean()
ndvi20 = collection20_b5.subtract(collection20_b4).divide(collection20_b5.add(collection20_b4)).rename('NDVI')

collection19_b5 = ee.ImageCollection('LANDSAT/LC08/C01/T1_TOA').select('B5').filterDate('2019-03-13', '2019-05-31').mean()
collection19_b4 = ee.ImageCollection('LANDSAT/LC08/C01/T1_TOA').select('B4').filterDate('2019-03-13', '2019-05-31').mean()
ndvi19 = collection19_b5.subtract(collection19_b4).divide(collection19_b5.add(collection19_b4)).rename('NDVI')

no2_diff = ndvi19.subtract(ndvi20)
no2_diff = no2_diff.divide(ndvi19).multiply(100)



roi = ee.Geometry.Rectangle([60-72, 5+30, 98.5+5-65, 37+30])
band_viz = {
  'min': -50,
  'max': 50,
  #'palette': ['yellow', 'orange', 'red']
  'palette': ['green','white', 'blue']
}
colormap = cm.LinearColormap(['green','white', 'blue'], vmin=-50, vmax=50)
#colormap = cm.linear.YlOrRd_09.scale(0, 0.0002).to_step(10)
colormap.caption = '% change in NDVI'
# no2_diff = collection19.subtract(collection20)
# no2_diff = no2_diff.divide(collection19).multiply(100)
mapid = no2_diff.clip(roi).getMapId(band_viz)

map = folium.Map(location=[24.11+27,75.27+5-67],zoom_start=3.8, height=550,width=600)

folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='NDVI',
    opacity=0.3,
  ).add_to(map)

map.add_child(folium.LayerControl())
map.add_child(colormap)
#folium.map.LayerControl('topleft', collapsed=False).add_to(map)
title_html = '''
             <h3 align="center" style="font-size:20px"><b>NDVI % change (2019-2020) </b></h3>
             '''
map.get_root().html.add_child(folium.Element(title_html))

map.save('ndvi_eu.html')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
collection20_b5 = ee.ImageCollection('LANDSAT/LC08/C01/T1_TOA').select('B5').filterDate('2020-03-23', '2020-05-31').mean()
collection20_b4 = ee.ImageCollection('LANDSAT/LC08/C01/T1_TOA').select('B4').filterDate('2020-03-23', '2020-05-31').mean()
ndvi20 = collection20_b5.subtract(collection20_b4).divide(collection20_b5.add(collection20_b4)).rename('NDVI')

collection19_b5 = ee.ImageCollection('LANDSAT/LC08/C01/T1_TOA').select('B5').filterDate('2019-03-23', '2019-05-31').mean()
collection19_b4 = ee.ImageCollection('LANDSAT/LC08/C01/T1_TOA').select('B4').filterDate('2019-03-23', '2019-05-31').mean()
ndvi19 = collection19_b5.subtract(collection19_b4).divide(collection19_b5.add(collection19_b4)).rename('NDVI')

no2_diff = ndvi19.subtract(ndvi20)
no2_diff = no2_diff.divide(ndvi19).multiply(100)



roi = ee.Geometry.Rectangle([60-200, 5+5, 98.5+5-150, 37+20])
band_viz = {
  'min': -50,
  'max': 50,
  #'palette': ['yellow', 'orange', 'red']
  'palette': ['green','white', 'blue']
}
colormap = cm.LinearColormap(['green','white', 'blue'], vmin=-50, vmax=50)
#colormap = cm.linear.YlOrRd_09.scale(0, 0.0002).to_step(10)
colormap.caption = '% change in NDVI'
# no2_diff = collection19.subtract(collection20)
# no2_diff = no2_diff.divide(collection19).multiply(100)
mapid = no2_diff.clip(roi).getMapId(band_viz)

map = folium.Map(location=[24.11+15,75.27+5-175],zoom_start=3.42, height=550,width=600)

folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='NDVI',
    opacity=0.3,
  ).add_to(map)

map.add_child(folium.LayerControl())
map.add_child(colormap)
#folium.map.LayerControl('topleft', collapsed=False).add_to(map)
title_html = '''
             <h3 align="center" style="font-size:20px"><b>NDVI % change (2019-2020) </b></h3>
             '''
map.get_root().html.add_child(folium.Element(title_html))

map.save('ndvi_na.html')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
collection20_b5 = ee.ImageCollection('LANDSAT/LC08/C01/T1_TOA').select('B5').filterDate('2020-03-13', '2020-05-31').mean()
collection20_b4 = ee.ImageCollection('LANDSAT/LC08/C01/T1_TOA').select('B4').filterDate('2020-03-13', '2020-05-31').mean()
ndvi20 = collection20_b5.subtract(collection20_b4).divide(collection20_b5.add(collection20_b4)).rename('NDVI')

collection19_b5 = ee.ImageCollection('LANDSAT/LC08/C01/T1_TOA').select('B5').filterDate('2019-03-13', '2019-05-31').mean()
collection19_b4 = ee.ImageCollection('LANDSAT/LC08/C01/T1_TOA').select('B4').filterDate('2019-03-13', '2019-05-31').mean()
ndvi19 = collection19_b5.subtract(collection19_b4).divide(collection19_b5.add(collection19_b4)).rename('NDVI')

no2_diff = ndvi19.subtract(ndvi20)
no2_diff = no2_diff.divide(ndvi19).multiply(100)


roi = ee.Geometry.Rectangle([60-200+30, 5+5-60, 98.5+5-150+30, 37+20-45])
band_viz = {
  'min': -50,
  'max': 50,
  #'palette': ['yellow', 'orange', 'red']
  'palette': ['green','white', 'blue']
}
colormap = cm.LinearColormap(['green','white', 'blue'], vmin=-50, vmax=50)
#colormap = cm.linear.YlOrRd_09.scale(0, 0.0002).to_step(10)
colormap.caption = '% change in NDVI'
# no2_diff = collection19.subtract(collection20)
# no2_diff = no2_diff.divide(collection19).multiply(100)
mapid = no2_diff.clip(roi).getMapId(band_viz)

map = folium.Map(location=[24.11+15-67,75.27+5-175+30],zoom_start=3.42, height=550,width=600)

folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='NDVI',
    opacity=0.3,
  ).add_to(map)

map.add_child(folium.LayerControl())
map.add_child(colormap)
#folium.map.LayerControl('topleft', collapsed=False).add_to(map)
title_html = '''
             <h3 align="center" style="font-size:20px"><b>NDVI % change (2019-2020) </b></h3>
             '''
map.get_root().html.add_child(folium.Element(title_html))

map.save('ndvi_sa.html')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
collection20_b5 = ee.ImageCollection('LANDSAT/LC08/C01/T1_TOA').select('B5').filterDate('2020-03-13', '2020-05-31').mean()
collection20_b4 = ee.ImageCollection('LANDSAT/LC08/C01/T1_TOA').select('B4').filterDate('2020-03-13', '2020-05-31').mean()
ndvi20 = collection20_b5.subtract(collection20_b4).divide(collection20_b5.add(collection20_b4)).rename('NDVI')

collection19_b5 = ee.ImageCollection('LANDSAT/LC08/C01/T1_TOA').select('B5').filterDate('2019-03-13', '2019-05-31').mean()
collection19_b4 = ee.ImageCollection('LANDSAT/LC08/C01/T1_TOA').select('B4').filterDate('2019-03-13', '2019-05-31').mean()
ndvi19 = collection19_b5.subtract(collection19_b4).divide(collection19_b5.add(collection19_b4)).rename('NDVI')

no2_diff = ndvi19.subtract(ndvi20)
no2_diff = no2_diff.divide(ndvi19).multiply(100)



roi = ee.Geometry.Rectangle([60-100+20, 5+5-40, 98.5+5-50+60-45, 37+20-45+20])
band_viz = {
  'min': -50,
  'max': 50,
  #'palette': ['yellow', 'orange', 'red']
  'palette': ['green','white', 'blue']
}
colormap = cm.LinearColormap(['green','white', 'blue'], vmin=-50, vmax=50)
#colormap = cm.linear.YlOrRd_09.scale(0, 0.0002).to_step(10)
colormap.caption = '% change in NDVI'
# no2_diff = collection19.subtract(collection20)
# no2_diff = no2_diff.divide(collection19).multiply(100)
mapid = no2_diff.clip(roi).getMapId(band_viz)

map = folium.Map(location=[24.11+15-67+30,75.27+5-75+30-10],zoom_start=3.42, height=550,width=600)

folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='NDVI',
    opacity=0.3,
  ).add_to(map)

map.add_child(folium.LayerControl())
map.add_child(colormap)
#folium.map.LayerControl('topleft', collapsed=False).add_to(map)
title_html = '''
             <h3 align="center" style="font-size:20px"><b>NDVI % change (2019-2020) </b></h3>
             '''
map.get_root().html.add_child(folium.Element(title_html))

map.save('ndvi_af.html')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
